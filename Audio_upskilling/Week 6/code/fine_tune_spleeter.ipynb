# %%
# !pip install spleeter
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.3/77.3 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.8/511.8 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 64.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 65.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 76.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 41.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 6.3 MB/s eta 0:00:00
# ...

# %%
# !spleeter train -p /content/drive/MyDrive/fine_tune_spleeter/musdb_config.json -d '/content/drive/MyDrive'
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:spleeter:Audio data loaded successfully
# INFO:spleeter:Audio data loaded successfully
# INFO:spleeter:Loading audio b'/content/drive/MyDrive/musdb/bass/Johnny Lokke - Promises & Lies.wav' from 0.0 to 20.0
# INFO:spleeter:Audio data loaded successfully
# INFO:spleeter:Loading audio b'/content/drive/MyDrive/musdb/drums/BKS - Bulldozer.wav' from 0.0 to 20.0
# INFO:spleeter:Loading audio b'/content/drive/MyDrive/musdb/mixture/Giselle - Moss.wav' from 0.5 to 20.5
# INFO:spleeter:Audio data loaded successfully
# INFO:spleeter:Loading audio b'/content/drive/MyDrive/musdb/vocals/Patrick Talbot - Set Me Free.wav' from 0.0 to 20.0
# INFO:spleeter:Audio data loaded successfully
# INFO:spleeter:Loading audio b'/content/drive/MyDrive/musdb/bass/Creepoid - OldTree.wav' from 0.0 to 20.0
# INFO:spleeter:Audio data loaded successfully
# INFO:spleeter:Loading audio b'/content/drive/MyDrive/musdb/other/Creepoid - OldTree.wav' from 0.0 to 20.0
# ...
